# %% [markdown]
# ### NBA Power Rankings Exercise

# %% [markdown]
# **About:**
#
#
# The data set used for this exercise contains **NBA’s Power Rankings** for weeks 2 through week 25 for the 2022-2023 NBA Season.
#
# * There are 30 teams in the NBA (in the 2022-2023 season).
#
# The "Power Ranking" is the order of the team's rank in the league that week. Thus, a 1 means 1st place (top team that week). 2 means 2nd place. 30 means last place. Each week, the the ranking can change as teams' records get better or worse.
#
# * **Each row** represents a different team, and
#
# * **each column** represents a different week.
#
#
# Here is a list of the team names and their corresponding row index in the data.

# %%
names = ['Atlanta Hawks','Boston Celtics','Brooklyn Nets','Charlotte Hornets',
        'Chicago Bulls','Cleveland Cavaliers','Dallas Maverics','Denver Nuggets',
        'Detroit Pistons','Golden State Warriors','Houston Rockets','Indana Pacers',
        'LA Clippers', 'LA Lakers','Memphis Grizzlies','Miami Heat','Milwaulkee Bucks',
        'MN Timberwolves','New Orleans Pelicans','NY Knicks','OK City Thunder','Orlando Magic',
        'Philadelphia 76ers','Phoenix Suns','Protland Trailblazers','Sacramento Kings',
        'San Antonio Spurs','Toronto Raptors','Utah Jazz','Washington Wizards']

# %%
for i in range(len(names)):
    print("Team ", i, "-", names[i])
# Out:
# Team  0 - Atlanta Hawks
# Team  1 - Boston Celtics
# Team  2 - Brooklyn Nets
# Team  3 - Charlotte Hornets
# Team  4 - Chicago Bulls
# Team  5 - Cleveland Cavaliers
# Team  6 - Dallas Maverics
# Team  7 - Denver Nuggets
# Team  8 - Detroit Pistons
# Team  9 - Golden State Warriors
# Team  10 - Houston Rockets
# Team  11 - Indana Pacers
# Team  12 - LA Clippers
# Team  13 - LA Lakers
# Team  14 - Memphis Grizzlies
# Team  15 - Miami Heat
# Team  16 - Milwaulkee Bucks
# Team  17 - MN Timberwolves
# Team  18 - New Orleans Pelicans
# Team  19 - NY Knicks
# Team  20 - OK City Thunder
# Team  21 - Orlando Magic
# Team  22 - Philadelphia 76ers
# Team  23 - Phoenix Suns
# Team  24 - Protland Trailblazers
# Team  25 - Sacramento Kings
# Team  26 - San Antonio Spurs
# Team  27 - Toronto Raptors
# Team  28 - Utah Jazz
# Team  29 - Washington Wizards

# %% [markdown]
# **Problem 1: Import matplotlib.pyplot and numpy** (as plt and np)

# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in ./venv/lib/python3.11/site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in ./venv/lib/python3.11/site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.11/site-packages (from plotly) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Problem 2: Use the loadtxt function from the numpy library to load the data.**

# %%
data = np.loadtxt("NBA_Power_Rankings.csv", delimiter = ",")

# %% [markdown]
# **Problem 3: Use .shape command to verify that the data set contains data for 30 different teams across 24 weeks.**

# %%
np.shape(data)
# Out:
# (30, 24)

# %% [markdown]
# **Problem 4: Choose a team from the list above and print their rankings across all 24 weeks.**
#
# Add a comment to your code cell stating the name of the team you chose.

# %%
# Input your answer in this cell:
# Team 9: Golden State Warriors

data[9,:]
# Out:
# array([ 3.,  9., 15., 19., 18., 10., 11., 11., 16., 18., 14., 13., 13.,
#        12., 10., 12., 16., 15., 13., 10., 11., 14., 12., 10.])

# %% [markdown]
# **Problem 5: What was the final ranking of the team that you chose.**

# %%
# Input your answer in this cell:
10
# Out:
# 10

# %% [markdown]
# **Problem 6: Calculate the Mean, Standard Deviation, Min, and Max rankings for the team you selected.**

# %%
# Input your answer in this cell:
team_9 = data[9,:]
team_9.mean(axis=0)
# Out:
# np.float64(12.708333333333334)

# %% [markdown]
# **Problem 7: Print the last column (week 25) of the data set.**

# %%
# Input your answer in this cell:
print(data[:, 23])
# Out:
# [20.  1. 13. 27. 18.  6. 21.  3. 30. 10. 28. 25. 11. 12.  7. 14.  2. 17.
#  15.  9. 16. 23.  4.  5. 26.  8. 29. 19. 22. 24.]

# %% [markdown]
# **Porblem 8: Calculate the average rankings for each of the 30 teams.**

# %%
for i in range(30):
    print(f"Team {i} Average Ranking: {data[i,:].mean(axis=0)}")
# Out:
# Team 0 Average Ranking: 15.5
# Team 1 Average Ranking: 1.8333333333333333
# Team 2 Average Ranking: 11.625
# Team 3 Average Ranking: 27.333333333333332
# Team 4 Average Ranking: 21.5
# Team 5 Average Ranking: 5.5
# Team 6 Average Ranking: 12.625
# Team 7 Average Ranking: 3.9583333333333335
# Team 8 Average Ranking: 28.541666666666668
# Team 9 Average Ranking: 12.708333333333334
# Team 10 Average Ranking: 28.625
# Team 11 Average Ranking: 20.916666666666668
# Team 12 Average Ranking: 12.833333333333334
# Team 13 Average Ranking: 20.958333333333332
# Team 14 Average Ranking: 6.708333333333333
# Team 15 Average Ranking: 14.375
# Team 16 Average Ranking: 3.1666666666666665
# Team 17 Average Ranking: 18.166666666666668
# Team 18 Average Ranking: 11.75
# Team 19 Average Ranking: 13.5
# Team 20 Average Ranking: 19.625
# Team 21 Average Ranking: 25.875
# Team 22 Average Ranking: 6.625
# Team 23 Average Ranking: 9.25
# Team 24 Average Ranking: 16.416666666666668
# Team 25 Average Ranking: 11.333333333333334
# Team 26 Average Ranking: 27.375
# Team 27 Average Ranking: 19.416666666666668
# Team 28 Average Ranking: 14.708333333333334
# Team 29 Average Ranking: 22.25

# %% [markdown]
# **Problem 9: Construct a line plot that showcases your team's ranking for each week.**

# %%
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x143e7b550>,
#  <matplotlib.lines.Line2D at 0x143ec0910>,
#  <matplotlib.lines.Line2D at 0x143ec3150>,
#  <matplotlib.lines.Line2D at 0x143ec3450>,
#  <matplotlib.lines.Line2D at 0x143ec3790>,
#  <matplotlib.lines.Line2D at 0x143ec3c10>,
#  <matplotlib.lines.Line2D at 0x143ecc110>,
#  <matplotlib.lines.Line2D at 0x142365990>,
#  <matplotlib.lines.Line2D at 0x143ecc750>,
#  <matplotlib.lines.Line2D at 0x143e74c50>,
#  <matplotlib.lines.Line2D at 0x143e74fd0>,
#  <matplotlib.lines.Line2D at 0x143ecd290>,
#  <matplotlib.lines.Line2D at 0x143ecd690>,
#  <matplotlib.lines.Line2D at 0x143ecda50>,
#  <matplotlib.lines.Line2D at 0x143ecde10>,
#  <matplotlib.lines.Line2D at 0x143ece210>,
#  <matplotlib.lines.Line2D at 0x143ece5d0>,
#  <matplotlib.lines.Line2D at 0x143ece9d0>,
#  <matplotlib.lines.Line2D at 0x143e3eed0>,
#  <matplotlib.lines.Line2D at 0x143e35750>,
#  <matplotlib.lines.Line2D at 0x13644eb50>,
#  <matplotlib.lines.Line2D at 0x143ecf8d0>,
#  <matplotlib.lines.Line2D at 0x1262c60d0>,
#  <matplotlib.lines.Line2D at 0x143e3b5d0>]
