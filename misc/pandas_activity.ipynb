# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("multidata.csv")

# %%
df.head()
# Out:
#   dataset          x          y
# 0       A  27.439632  65.744463
# 1       A  27.939519  50.985062
# 2       A  28.564138  34.626400
# 3       A  28.809402  59.621004
# 4       A  30.343361  32.524563

# %%
df.tail()
# Out:
#      dataset        x        y
# 1841       Y  89.4872  42.5641
# 1842       Y  91.2821  41.5385
# 1843       Y  93.3333  39.8718
# 1844       Y  95.3846  36.7949
# 1845       Y  98.2051  33.7180

# %%
df["dataset"].unique()
# Out:
# array(['A', 'C', 'E', 'G', 'I', 'K', 'M', 'O', 'Q', 'S', 'U', 'W', 'Y'],
#       dtype=object)

# %%
filtered_df = df.loc[df["dataset"] == "U"]

# %%
print(filtered_df)
# Out:
#      dataset          x          y
# 1420       U  22.003709  50.499440
# 1421       U  22.817107  30.436040
# 1422       U  22.955093  70.426895
# 1423       U  23.284748  50.474353
# 1424       U  24.270382  50.485568
# ...      ...        ...        ...
# 1557       U  88.662664  50.455326
# 1558       U  91.112085  50.489389
# 1559       U  95.065275  30.500403
# 1560       U  95.249234  30.459454
# 1561       U  98.288123  30.603919
#
# [142 rows x 3 columns]

# %%
plt.plot(filtered_df['x'],filtered_df['y'], '.')

# %%
dslabels = df['dataset'].unique()

# %%
dslabels
# Out:
# array(['A', 'C', 'E', 'G', 'I', 'K', 'M', 'O', 'Q', 'S', 'U', 'W', 'Y'],
#       dtype=object)

# %%
for i in dslabels:
    mydf = df.loc[df["dataset"]==i]
    plt.figure(figsize=(5,5))
    plt.plot(mydf['x'], mydf['y'], '.')
    plt.title(f"Dataset {i}")
    plt.show()
